# %% [markdown]
# ## Analysis of XRP data based on rolling averages

# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm

# %%
XRP_increase = pd.read_csv("XRP_Increase_SmallAmount.csv")

# %%
XRP_decrease = pd.read_csv("XRP_Decrease_SmallAmount.csv")

# %%
try:
    del XRP_increase['Decrease_0.1_percent']
except:
    print('Not found')

# %%
#### For getting rid of rounding error

# %%
regex = r"[0000]+[0-9]+[_]"

# %%
for col in [d for d in XRP_decrease.columns if '_percent' in d]:
    print(col , ',,' , re.sub(regex, '_',col))
    XRP_decrease.rename(columns= {col : re.sub(regex, '_',col)}, inplace = True)
# Out:
# Decrease_0.1_percent ,, Decrease_0.1_percent
# Decrease_0.2_percent ,, Decrease_0.2_percent
# Decrease_0.30000000000000004_percent ,, Decrease_0.3_percent
# Decrease_0.4_percent ,, Decrease_0.4_percent
# Decrease_0.5_percent ,, Decrease_0.5_percent
# Decrease_0.6000000000000001_percent ,, Decrease_0.6_percent
# Decrease_0.8_percent ,, Decrease_0.8_percent
# Decrease_1.0_percent ,, Decrease_1.0_percent
# Decrease_1.5_percent ,, Decrease_1.5_percent

# %%
for col in [d for d in XRP_increase.columns if '_percent' in d]:
    print(col , ',,' , re.sub(regex, '_',col))
    XRP_increase.rename(columns= {col : re.sub(regex, '_',col)}, inplace = True)
# Out:
# Increase_0.1_percent ,, Increase_0.1_percent
# Increase_0.2_percent ,, Increase_0.2_percent
# Increase_0.30000000000000004_percent ,, Increase_0.3_percent
# Increase_0.4_percent ,, Increase_0.4_percent
# Increase_0.5_percent ,, Increase_0.5_percent
# Increase_0.6000000000000001_percent ,, Increase_0.6_percent
# Increase_0.8_percent ,, Increase_0.8_percent
# Increase_1.0_percent ,, Increase_1.0_percent
# Increase_1.5_percent ,, Increase_1.5_percent

# %%
list(np.intersect1d(XRP_decrease.columns,XRP_increase.columns))
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'close',
#  'date',
#  'datetime_real',
#  'high',
#  'low',
#  'open',
#  'quoteVolume',
#  'volume',
#  'weightedAverage']

# %%
[d for d in XRP_decrease.columns if '_percent' in d]
# Out:
# ['Decrease_0.1_percent',
#  'Decrease_0.2_percent',
#  'Decrease_0.3_percent',
#  'Decrease_0.4_percent',
#  'Decrease_0.5_percent',
#  'Decrease_0.6_percent',
#  'Decrease_0.8_percent',
#  'Decrease_1.0_percent',
#  'Decrease_1.5_percent']

# %%
intersect_columns = [d for d in np.intersect1d(XRP_decrease.columns,XRP_increase.columns) if d not in ['Unnamed: 0','Unnamed: 0.1']]

# %%
XRP_Analysis_table = XRP_increase[intersect_columns + ['Increase_0.2_percent','Increase_0.3_percent','Increase_0.4_percent']]

# %%
XRP_Analysis_table = XRP_Analysis_table.merge(XRP_decrease[['date','Decrease_0.1_percent','Decrease_0.2_percent','Decrease_0.3_percent','Decrease_0.4_percent']], on='date',how = 'left')

# %% [markdown]
# ## XRP_Analysis_table

# %% [markdown]
# ## Currently:
# - increase 0.2, decrease 0.1

# %%
XRP_Analysis_table.head()
# Out:
#       close        date        datetime_real      high       low      open  \
# 0  0.024997  1424462400  2015-02-20 20:00:00  0.024997  0.024997  0.024997
# 1  0.024997  1424464200  2015-02-20 20:30:00  0.024997  0.024997  0.024997
# 2  0.024997  1424466000  2015-02-20 21:00:00  0.024997  0.024997  0.024997
# 3  0.024997  1424467800  2015-02-20 21:30:00  0.024997  0.024997  0.024997
# 4  0.024997  1424469600  2015-02-20 22:00:00  0.024997  0.024997  0.024997
#
#    quoteVolume    volume  weightedAverage  Increase_0.2_percent  \
# 0       0.1467  0.003667         0.024997            1455001200
# 1       0.0000  0.000000         0.024997            1455001200
# 2       0.0000  0.000000         0.024997            1455001200
# 3       0.0000  0.000000         0.024997            1455001200
# 4       0.0000  0.000000         0.024997            1455001200
#
#    Increase_0.3_percent  Increase_0.4_percent  Decrease_0.1_percent  \
# 0            1455001200            1455001200            1424964600
# 1            1455001200            1455001200            1424964600
# 2            1455001200            1455001200            1424964600
# 3            1455001200            1455001200            1424964600
# 4            1455001200            1455001200            1424964600
#
#    Decrease_0.2_percent  Decrease_0.3_percent  Decrease_0.4_percent
# 0            1424964600            1424964600            1424964600
# 1            1424964600            1424964600            1424964600
# 2            1424964600            1424964600            1424964600
# 3            1424964600            1424964600            1424964600
# 4            1424964600            1424964600            1424964600

# %%
from matplotlib.pylab import rcParams

# %%
rcParams['figure.figsize'] = 20,10

# %%
# XRP_in1_de1['1H_RA_on_Close'] = XRP_in1_de1['close'].rolling(2).mean()
XRP_Analysis_table['2H_RA_on_Close'] = XRP_Analysis_table['close'].rolling(2*2).mean()

# XRP_in1_de1['4H_RA_on_Close'] = XRP_in1_de1['close'].rolling(2*2).mean()
# XRP_in1_de1['8H_RA_on_Close'] = XRP_in1_de1['close'].rolling(2*2).mean()
# XRP_in1_de1['12H_RA_on_Close'] = XRP_in1_de1['close'].rolling(2*2).mean()

# %%
XRP_Analysis_table['2H_RA_on_Close'] = XRP_Analysis_table['2H_RA_on_Close'].shift(1) # due to information needs to be for before

# %% [markdown]
# ####  2H rolling seems okay

# %%
XRP_Analysis_table[['high','low','2H_RA_on_Close','close','datetime_real']][-28:].set_index('datetime_real').plot(title = '{}'.format('Last 600'))

# %%
XRP_Analysis_table[-28:]['high'].max()
# Out:
# 0.31676036

# %%
0.31208458
# Out:
# 0.31208458

# %%
(0.31676036 - 0.31208458)/0.31208458
# Out:
# 0.014982412780535387

# %%
test_code = XRP_Analysis_table[-5000:]

# %%
len(test_code)
# Out:
# 5000

# %%
test_code['increa_decre'] = test_code['Increase_0.2_percent'] < test_code['Decrease_0.1_percent']
# Out:
# c:\users\zhen\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_code['is_decre'] = test_code['Increase_0.2_percent'] >= test_code['Decrease_0.1_percent']
# Out:
# c:\users\zhen\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
winning_percent = test_code[test_code['increa_decre']]

# %%
test_code['below_2H_RA'] =  (test_code['low'] - test_code['2H_RA_on_Close'])/test_code['2H_RA_on_Close']
# Out:
# c:\users\zhen\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_code['colour'] = test_code['increa_decre'].apply(lambda x: 'Green' if x else 'Orange')
# Out:
# c:\users\zhen\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_code.head()
# Out:
#           close        date        datetime_real      high       low  \
# 72735  0.330390  1555709400  2019-04-19 22:30:00  0.330688  0.330390
# 72736  0.330390  1555711200  2019-04-19 23:00:00  0.330390  0.330390
# 72737  0.329000  1555713000  2019-04-19 23:30:00  0.329600  0.329000
# 72738  0.330524  1555714800  2019-04-20 00:00:00  0.330524  0.329078
# 72739  0.330524  1555716600  2019-04-20 00:30:00  0.330524  0.330524
#
#            open   quoteVolume       volume  weightedAverage  \
# 72735  0.330427    720.492935   238.163179         0.330556
# 72736  0.330390      0.000000     0.000000         0.330390
# 72737  0.329600  24563.194229  8082.315862         0.329042
# 72738  0.329078  15585.684631  5148.066171         0.330307
# 72739  0.330524      0.000000     0.000000         0.330524
#
#        Increase_0.2_percent  ...  Increase_0.4_percent  Decrease_0.1_percent  \
# 72735            1555736400  ...            1555740000            1555713000
# 72736            1555736400  ...            1555740000            1555713000
# 72737            1555714800  ...            1555714800            1555732800
# 72738            1555716600  ...            1555716600            1555732800
# 72739            1555738200  ...            1555747200            1555718400
#
#        Decrease_0.2_percent  Decrease_0.3_percent  Decrease_0.4_percent  \
# 72735            1555713000            1555713000            1555713000
# 72736            1555713000            1555713000            1555713000
# 72737            1555754400            1555754400            1555790400
# 72738            1555754400            1555754400            1555790400
# 72739            1555722000            1555722000            1555732800
#
#        2H_RA_on_Close  increa_decre  is_decre  below_2H_RA  colour
# 72735        0.330455         False      True    -0.000195  Orange
# 72736        0.330190         False      True     0.000606  Orange
# 72737        0.330172          True     False    -0.003551   Green
# 72738        0.330009          True     False    -0.002822   Green
# 72739        0.330076         False      True     0.001356  Orange
#
# [5 rows x 21 columns]

# %% [markdown]
# ### try with by feeding low first, then high, and again with high, then low

# %%
starting_asset = 100

# %%
test_code.head()
# Out:
#           close        date        datetime_real      high       low  \
# 72735  0.330390  1555709400  2019-04-19 22:30:00  0.330688  0.330390
# 72736  0.330390  1555711200  2019-04-19 23:00:00  0.330390  0.330390
# 72737  0.329000  1555713000  2019-04-19 23:30:00  0.329600  0.329000
# 72738  0.330524  1555714800  2019-04-20 00:00:00  0.330524  0.329078
# 72739  0.330524  1555716600  2019-04-20 00:30:00  0.330524  0.330524
#
#            open   quoteVolume       volume  weightedAverage  \
# 72735  0.330427    720.492935   238.163179         0.330556
# 72736  0.330390      0.000000     0.000000         0.330390
# 72737  0.329600  24563.194229  8082.315862         0.329042
# 72738  0.329078  15585.684631  5148.066171         0.330307
# 72739  0.330524      0.000000     0.000000         0.330524
#
#        Increase_0.2_percent  ...  Increase_0.4_percent  Decrease_0.1_percent  \
# 72735            1555736400  ...            1555740000            1555713000
# 72736            1555736400  ...            1555740000            1555713000
# 72737            1555714800  ...            1555714800            1555732800
# 72738            1555716600  ...            1555716600            1555732800
# 72739            1555738200  ...            1555747200            1555718400
#
#        Decrease_0.2_percent  Decrease_0.3_percent  Decrease_0.4_percent  \
# 72735            1555713000            1555713000            1555713000
# 72736            1555713000            1555713000            1555713000
# 72737            1555754400            1555754400            1555790400
# 72738            1555754400            1555754400            1555790400
# 72739            1555722000            1555722000            1555732800
#
#        2H_RA_on_Close  increa_decre  is_decre  below_2H_RA  colour
# 72735        0.330455         False      True    -0.000195  Orange
# 72736        0.330190         False      True     0.000606  Orange
# 72737        0.330172          True     False    -0.003551   Green
# 72738        0.330009          True     False    -0.002822   Green
# 72739        0.330076         False      True     0.001356  Orange
#
# [5 rows x 21 columns]

# %%
plt.plot(test_code['date'], test_code['low'])
plt.plot(test_code['date'], test_code['high'])
plt.plot(test_code['date'], test_code['close'], 'k--')
plt.plot(test_code['date'], test_code['2H_RA_on_Close'], 'g--')

# %%
len(test_code)
# Out:
# 5000

# %%
np.arange(0,len(test_code), 500)
# Out:
# array([   0,  500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500])

# %%
break_down_points = np.arange(0,len(test_code), 500)

for value in break_down_points:
    temp_table = test_code[value: value+50]
    
    plt.plot(temp_table['date'], temp_table['low'], label ='low')
    plt.plot(temp_table['date'], temp_table['high'], label ='high')
    plt.plot(temp_table['date'], temp_table['close'], 'k--', label ='close')
    plt.plot(temp_table['date'], temp_table['2H_RA_on_Close'], 'g--', label ='2H_RA_on_Close')
    plt.title('{0} -->  {1}'.format(temp_table['datetime_real'].min(), temp_table['datetime_real'].max()))
    plt.grid()
    plt.legend()
    plt.show()
    break

# %%
x = test_code['date']
y = test_code['low']
color = test_code['colour']



for x_p, x_p1, y_p, y_p1 , c_p in zip(x, x[1:] , y, y[1:], color):
    if c_p == 'Green':
        plt.plot([x_p,x_p1], [y_p,y_p1], 'g-')
        
    else:
        plt.plot([x_p,x_p1], [y_p,y_p1] ,'r')


plt.plot(test_code['date'], test_code['2H_RA_on_Close'], 'b--')
plt.grid()
plt.show()

# %%
g1 = test_code[~test_code['increa_decre']][['date','below_2H_RA']]
g2 = test_code[test_code['increa_decre']][['date','below_2H_RA']]

plt.plot(g1['date'], g1['below_2H_RA'], 'r', label = 'loss')
plt.plot(g2['date'], g2['below_2H_RA'] , 'g' , label =  'gain')

plt.hlines(y= 0 , xmin = test_code['date'].min() , xmax= test_code['date'].max())
plt.grid()
plt.show()

# %%
pd.DataFrame([10,10,30]).describe()

# %%
pd.DataFrame([1,1,3]).describe()
# Out:
#               0
# count  3.000000
# mean   1.666667
# std    1.154701
# min    1.000000
# 25%    1.000000
# 50%    1.000000
# 75%    2.000000
# max    3.000000

# %%
g1['below_2H_RA'].describe()
# Out:
# count    2044.000000
# mean       -0.003053
# std         0.008431
# min        -0.099928
# 25%        -0.005704
# 50%        -0.001611
# 75%         0.001089
# max         0.029846
# Name: below_2H_RA, dtype: float64

# %%
g2['below_2H_RA'].describe()
# Out:
# count    2956.000000
# mean       -0.004686
# std         0.009827
# min        -0.107349
# 25%        -0.007210
# 50%        -0.003047
# 75%         0.000061
# max         0.035470
# Name: below_2H_RA, dtype: float64

# %%
g1.merge(g2, on ='date', how='outer').boxplot(column=['below_2H_RA_x','below_2H_RA_y'])

# %%
test_code[test_code['increa_decre']][['date','below_2H_RA']].set_index('date').plot()

# %%
x = test_code['date']
y = test_code['close']
y_low = test_code['low']
y_high = test_code['high']
ra = test_code['2H_RA_on_Close']
color = test_code['colour']

for x_p, x_p1, y_p, y_p1 , c_p in zip(x, x[1:] , y, y[1:], color):
    if c_p == 'Green':
        plt.plot([x_p,x_p1], [y_p,y_p1], 'g-')
        
    else:
        plt.plot([x_p,x_p1], [y_p,y_p1] ,'r')
        
plt.plot(x, ra,'--')
plt.plot(x, y_low,'orange')
plt.plot(x, y_high, 'b--')
plt.show()

# %% [markdown]
# ## Running trade

# %% [markdown]
# - for 0.004 before 2H

# %% [markdown]
# 0.4% below
#
# each trade costs: 0.2% (so each sell needs to deduct 0.2%)
#
# low supply first, then high

# %%
XRP_Analysis_table.head()
# Out:
#       close        date        datetime_real      high       low      open  \
# 0  0.024997  1424462400  2015-02-20 20:00:00  0.024997  0.024997  0.024997
# 1  0.024997  1424464200  2015-02-20 20:30:00  0.024997  0.024997  0.024997
# 2  0.024997  1424466000  2015-02-20 21:00:00  0.024997  0.024997  0.024997
# 3  0.024997  1424467800  2015-02-20 21:30:00  0.024997  0.024997  0.024997
# 4  0.024997  1424469600  2015-02-20 22:00:00  0.024997  0.024997  0.024997
#
#    quoteVolume    volume  weightedAverage  Increase_0.2_percent  \
# 0       0.1467  0.003667         0.024997            1455001200
# 1       0.0000  0.000000         0.024997            1455001200
# 2       0.0000  0.000000         0.024997            1455001200
# 3       0.0000  0.000000         0.024997            1455001200
# 4       0.0000  0.000000         0.024997            1455001200
#
#    Increase_0.3_percent  Increase_0.4_percent  Decrease_0.1_percent  \
# 0            1455001200            1455001200            1424964600
# 1            1455001200            1455001200            1424964600
# 2            1455001200            1455001200            1424964600
# 3            1455001200            1455001200            1424964600
# 4            1455001200            1455001200            1424964600
#
#    Decrease_0.2_percent  Decrease_0.3_percent  Decrease_0.4_percent  \
# 0            1424964600            1424964600            1424964600
# 1            1424964600            1424964600            1424964600
# 2            1424964600            1424964600            1424964600
# 3            1424964600            1424964600            1424964600
# 4            1424964600            1424964600            1424964600
#
#    2H_RA_on_Close
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4        0.024997

# %%
def action_decision(action_time, value, RA_2H_Value):
# Out:
#   File "<ipython-input-57-b687f8bdaaa1>", line 7
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
for ind, df in XRP_Analysis_table[-5:].iterrows():
    print(df['date'])
# Out:
# 1564695000
# 1564696800
# 1564698600
# 1564700400
# 1564702200

# %%
XRP_Analysis_table[XRP_Analysis_table['datetime_real'] > '2017-07-07']
# Out:
#           close        date        datetime_real      high       low  \
# 41421  0.248810  1499382000  2017-07-07 00:00:00  0.249578  0.248800
# 41422  0.248800  1499383800  2017-07-07 00:30:00  0.249611  0.248800
# 41423  0.248800  1499385600  2017-07-07 01:00:00  0.249640  0.248800
# 41424  0.251000  1499387400  2017-07-07 01:30:00  0.251000  0.248800
# 41425  0.248800  1499389200  2017-07-07 02:00:00  0.251000  0.248800
# 41426  0.250051  1499391000  2017-07-07 02:30:00  0.250051  0.248800
# 41427  0.248800  1499392800  2017-07-07 03:00:00  0.250051  0.248800
# 41428  0.247143  1499394600  2017-07-07 03:30:00  0.250000  0.247143
# 41429  0.247774  1499396400  2017-07-07 04:00:00  0.248000  0.247107
# 41430  0.246400  1499398200  2017-07-07 04:30:00  0.248600  0.246400
# 41431  0.246753  1499400000  2017-07-07 05:00:00  0.247182  0.245400
# 41432  0.246700  1499401800  2017-07-07 05:30:00  0.247741  0.245926
# 41433  0.246700  1499403600  2017-07-07 06:00:00  0.246700  0.245927
# 41434  0.246133  1499405400  2017-07-07 06:30:00  0.247706  0.246000
# 41435  0.246587  1499407200  2017-07-07 07:00:00  0.247800  0.246059
# 41436  0.244926  1499409000  2017-07-07 07:30:00  0.246587  0.244926
# 41437  0.243700  1499410800  2017-07-07 08:00:00  0.244926  0.241927
# 41438  0.238084  1499412600  2017-07-07 08:30:00  0.242502  0.237800
# 41439  0.236094  1499414400  2017-07-07 09:00:00  0.240300  0.235801
# 41440  0.237471  1499416200  2017-07-07 09:30:00  0.237471  0.235600
# 41441  0.238089  1499418000  2017-07-07 10:00:00  0.239294  0.235667
# 41442  0.237500  1499419800  2017-07-07 10:30:00  0.238893  0.237500
# 41443  0.238000  1499421600  2017-07-07 11:00:00  0.238172  0.236500
# 41444  0.240110  1499423400  2017-07-07 11:30:00  0.240110  0.236352
# 41445  0.235667  1499425200  2017-07-07 12:00:00  0.241110  0.235667
# 41446  0.234400  1499427000  2017-07-07 12:30:00  0.237770  0.234400
# 41447  0.233501  1499428800  2017-07-07 13:00:00  0.234800  0.233501
# 41448  0.230600  1499430600  2017-07-07 13:30:00  0.235300  0.230022
# 41449  0.234918  1499432400  2017-07-07 14:00:00  0.236079  0.232499
# 41450  0.229861  1499434200  2017-07-07 14:30:00  0.233600  0.229861
# ...         ...         ...                  ...       ...       ...
# 77705  0.313781  1564650000  2019-08-01 10:00:00  0.313894  0.313005
# 77706  0.313000  1564651800  2019-08-01 10:30:00  0.314300  0.313000
# 77707  0.312663  1564653600  2019-08-01 11:00:00  0.314022  0.312663
# 77708  0.312362  1564655400  2019-08-01 11:30:00  0.313071  0.312362
# 77709  0.312821  1564657200  2019-08-01 12:00:00  0.313071  0.312256
# 77710  0.312821  1564659000  2019-08-01 12:30:00  0.312821  0.312821
# 77711  0.313605  1564660800  2019-08-01 13:00:00  0.314208  0.313071
# 77712  0.313404  1564662600  2019-08-01 13:30:00  0.314076  0.313404
# 77713  0.313404  1564664400  2019-08-01 14:00:00  0.313881  0.313404
# 77714  0.313881  1564666200  2019-08-01 14:30:00  0.313881  0.313095
# 77715  0.312941  1564668000  2019-08-01 15:00:00  0.313684  0.312941
# 77716  0.312085  1564669800  2019-08-01 15:30:00  0.312941  0.312085
# 77717  0.312671  1564671600  2019-08-01 16:00:00  0.312671  0.312477
# 77718  0.313879  1564673400  2019-08-01 16:30:00  0.313881  0.312641
# 77719  0.313153  1564675200  2019-08-01 17:00:00  0.313659  0.312981
# 77720  0.313881  1564677000  2019-08-01 17:30:00  0.313881  0.313769
# 77721  0.313283  1564678800  2019-08-01 18:00:00  0.313881  0.313283
# 77722  0.313868  1564680600  2019-08-01 18:30:00  0.313881  0.313797
# 77723  0.313567  1564682400  2019-08-01 19:00:00  0.314368  0.313567
# 77724  0.313459  1564684200  2019-08-01 19:30:00  0.313684  0.313368
# 77725  0.312870  1564686000  2019-08-01 20:00:00  0.313459  0.312870
# 77726  0.313304  1564687800  2019-08-01 20:30:00  0.313459  0.312870
# 77727  0.313310  1564689600  2019-08-01 21:00:00  0.314367  0.312870
# 77728  0.315438  1564691400  2019-08-01 21:30:00  0.315439  0.313868
# 77729  0.316400  1564693200  2019-08-01 22:00:00  0.316511  0.315439
# 77730  0.316574  1564695000  2019-08-01 22:30:00  0.316574  0.316574
# 77731  0.315473  1564696800  2019-08-01 23:00:00  0.316760  0.315473
# 77732  0.316326  1564698600  2019-08-01 23:30:00  0.316336  0.315803
# 77733  0.316000  1564700400  2019-08-02 00:00:00  0.316000  0.315656
# 77734  0.315153  1564702200  2019-08-02 00:30:00  0.315153  0.315153
#
#            open    quoteVolume         volume  weightedAverage  \
# 41421  0.248800   17507.926785    4360.708416         0.249071
# 41422  0.248810   92871.584722   23146.293877         0.249229
# 41423  0.248800  112189.248493   27955.485576         0.249182
# 41424  0.248800  123234.843103   30778.310692         0.249753
# 41425  0.251000   68289.968327   17044.833933         0.249595
# 41426  0.248800   31900.590292    7952.545951         0.249291
# 41427  0.250000   49775.108129   12389.273908         0.248905
# 41428  0.248800  135533.760057   33550.050609         0.247540
# 41429  0.247115   64025.244244   15845.840204         0.247494
# 41430  0.247774   73000.491326   17999.096486         0.246561
# 41431  0.246400  120935.967508   29787.216864         0.246306
# 41432  0.246753  130472.263234   32160.235225         0.246491
# 41433  0.246700   38366.901188    9453.361025         0.246394
# 41434  0.246700   29211.995027    7195.404000         0.246317
# 41435  0.247006   51274.139989   12650.184956         0.246717
# 41436  0.246587  108852.348396   26732.026698         0.245581
# 41437  0.244926  218890.577625   53153.920398         0.242833
# 41438  0.242502  345575.428790   82949.224917         0.240032
# 41439  0.238084  382967.441546   91047.104662         0.237741
# 41440  0.236094  183137.804083   43211.430563         0.235950
# 41441  0.237987   81810.510584   19342.258475         0.236428
# 41442  0.238089    5650.331630    1346.795245         0.238357
# 41443  0.238172    6994.009353    1658.671692         0.237156
# 41444  0.237559   95221.938503   22590.838077         0.237244
# 41445  0.240172   94984.007458   22633.243361         0.238285
# 41446  0.237770  166511.123870   39204.076831         0.235444
# 41447  0.234270  135966.547399   31871.216762         0.234405
# 41448  0.233501  462524.015359  107659.871129         0.232766
# 41449  0.232499  236677.266173   55321.118123         0.233741
# 41450  0.233600  123853.177476   28576.140070         0.230726
# ...         ...            ...            ...              ...
# 77705  0.313894    5325.051816    1668.044035         0.313245
# 77706  0.313775   32755.226361   10260.112987         0.313236
# 77707  0.314022   24114.075320    7550.254424         0.313106
# 77708  0.312717    1864.576647     583.692933         0.313043
# 77709  0.312844    5060.203248    1582.388412         0.312712
# 77710  0.312821       0.000000       0.000000         0.312821
# 77711  0.313071    9677.841439    3035.116300         0.313615
# 77712  0.314076   20131.313111    6314.517367         0.313666
# 77713  0.313404    1547.300929     485.442802         0.313735
# 77714  0.313366    9994.037618    3130.653765         0.313252
# 77715  0.313684    6484.172506    2031.657206         0.313326
# 77716  0.312902     627.625516     196.168017         0.312556
# 77717  0.312480     466.574352     145.846530         0.312590
# 77718  0.312641    3183.019597     997.259713         0.313306
# 77719  0.313659    1244.863413     389.629177         0.312989
# 77720  0.313769      24.029588       7.540266         0.313791
# 77721  0.313881     847.617236     266.034660         0.313862
# 77722  0.313881    1458.939300     457.896722         0.313856
# 77723  0.313571   15184.354641    4771.347392         0.314228
# 77724  0.313567     654.356545     205.066394         0.313386
# 77725  0.313436   52164.085566   16349.785244         0.313430
# 77726  0.312870    1963.762238     615.305200         0.313330
# 77727  0.313304   29178.710699    9141.549479         0.313295
# 77728  0.313868   11151.621353    3508.734802         0.314639
# 77729  0.315439   40525.552978   12791.365591         0.315637
# 77730  0.316574     150.000000      47.486089         0.316574
# 77731  0.315500   39158.856978   12356.390327         0.315545
# 77732  0.315803   15843.524305    5010.950504         0.316278
# 77733  0.315656   28172.677719    8902.231734         0.315988
# 77734  0.315153   10000.000000    3151.533000         0.315153
#
#        Increase_0.2_percent  Increase_0.3_percent  Increase_0.4_percent  \
# 41421            1499383800            1499383800            1499387400
# 41422            1499385600            1499385600            1499387400
# 41423            1499387400            1499387400            1499387400
# 41424            1499389200            1499389200            1499389200
# 41425            1499391000            1499391000            1499391000
# 41426            1499392800            1499392800            1499392800
# 41427            1499394600            1499394600            1499394600
# 41428            1499396400            1499396400            1499398200
# 41429            1499398200            1499398200            1499398200
# 41430            1499400000            1499400000            1499401800
# 41431            1499401800            1499401800            1499401800
# 41432            1499403600            1499403600            1499405400
# 41433            1499405400            1499405400            1499405400
# 41434            1499407200            1499407200            1499407200
# 41435            1499409000            1503421200            1503421200
# 41436            1503421200            1503421200            1503421200
# 41437            1499412600            1503421200            1503421200
# 41438            1499414400            1499414400            1499414400
# 41439            1499416200            1499416200            1499416200
# 41440            1499418000            1499418000            1499418000
# 41441            1499419800            1499419800            1499419800
# 41442            1499421600            1499423400            1499423400
# 41443            1499423400            1499423400            1499423400
# 41444            1499425200            1499425200            1499425200
# 41445            1499427000            1499427000            1499427000
# 41446            1499430600            1499430600            1499432400
# 41447            1499430600            1499430600            1499430600
# 41448            1499432400            1499432400            1499432400
# 41449            1499434200            1499434200            1499434200
# 41450            1499436000            1499436000            1499436000
# ...                     ...                   ...                   ...
# 77705            1564651800            1564651800            1564651800
# 77706            1564653600            1564653600            1564682400
# 77707            1564660800            1564660800            1564660800
# 77708            1564657200            1564660800            1564660800
# 77709            1564660800            1564660800            1564660800
# 77710            1564660800            1564660800            1564660800
# 77711            1564662600            1564662600            1564682400
# 77712            1564682400            1564682400            1564691400
# 77713            1564682400            1564682400            1564691400
# 77714            1564673400            1564682400            1564682400
# 77715            1564673400            1564673400            1564682400
# 77716            1564673400            1564673400            1564673400
# 77717            1564673400            1564673400            1564673400
# 77718            1564675200            1564675200            1564682400
# 77719            1564677000            1564682400            1564682400
# 77720            1564691400            1564691400            1564691400
# 77721            1564682400            1564682400            1564691400
# 77722            1564691400            1564691400            1564691400
# 77723            1564689600            1564691400            1564691400
# 77724            1564689600            1564689600            1564691400
# 77725            1564689600            1564689600            1564689600
# 77726            1564689600            1564689600            1564689600
# 77727            1564691400            1564691400            1564691400
# 77728            1564693200            1564693200            1564693200
# 77729            1564695000            1564695000            1564696800
# 77730            3456789123            3456789123            3456789123
# 77731            1564698600            3456789123            3456789123
# 77732            3456789123            3456789123            3456789123
# 77733            3456789123            3456789123            3456789123
# 77734            3456789123            3456789123            3456789123
#
#        Decrease_0.1_percent  Decrease_0.2_percent  Decrease_0.3_percent  \
# 41421            1499394600            1499394600            1499394600
# 41422            1499394600            1499394600            1499394600
# 41423            1499394600            1499394600            1499394600
# 41424            1499394600            1499394600            1499394600
# 41425            1499394600            1499394600            1499394600
# 41426            1499394600            1499394600            1499394600
# 41427            1499394600            1499394600            1499394600
# 41428            1499398200            1499398200            1499398200
# 41429            1499398200            1499398200            1499400000
# 41430            1499400000            1499400000            1499400000
# 41431            1499409000            1499410800            1499410800
# 41432            1499409000            1499409000            1499409000
# 41433            1499409000            1499409000            1499409000
# 41434            1499409000            1499409000            1499409000
# 41435            1499409000            1499409000            1499409000
# 41436            1499410800            1499410800            1499410800
# 41437            1499412600            1499412600            1499412600
# 41438            1499414400            1499414400            1499414400
# 41439            1499427000            1499427000            1499427000
# 41440            1499427000            1499427000            1499427000
# 41441            1499427000            1499427000            1499427000
# 41442            1499421600            1499421600            1499421600
# 41443            1499425200            1499425200            1499425200
# 41444            1499425200            1499425200            1499427000
# 41445            1499427000            1499427000            1499427000
# 41446            1499428800            1499428800            1499428800
# 41447            1499430600            1499430600            1499430600
# 41448            1499436000            1499436000            1499436000
# 41449            1499434200            1499434200            1499434200
# 41450            1499436000            1499436000            1499436000
# ...                     ...                   ...                   ...
# 77705            1564653600            1564655400            3456789123
# 77706            1564653600            1564655400            3456789123
# 77707            1564657200            3456789123            3456789123
# 77708            3456789123            3456789123            3456789123
# 77709            3456789123            3456789123            3456789123
# 77710            1564669800            1564669800            3456789123
# 77711            1564669800            1564669800            1564669800
# 77712            1564668000            1564669800            1564669800
# 77713            1564668000            1564669800            1564669800
# 77714            1564669800            1564669800            1564669800
# 77715            1564669800            1564669800            3456789123
# 77716            3456789123            3456789123            3456789123
# 77717            3456789123            3456789123            3456789123
# 77718            3456789123            3456789123            3456789123
# 77719            3456789123            3456789123            3456789123
# 77720            1564678800            1564686000            3456789123
# 77721            1564686000            3456789123            3456789123
# 77722            1564684200            1564686000            3456789123
# 77723            1564686000            1564686000            3456789123
# 77724            1564686000            3456789123            3456789123
# 77725            3456789123            3456789123            3456789123
# 77726            3456789123            3456789123            3456789123
# 77727            3456789123            3456789123            3456789123
# 77728            3456789123            3456789123            3456789123
# 77729            3456789123            3456789123            3456789123
# 77730            1564696800            1564696800            1564696800
# 77731            1564702200            3456789123            3456789123
# 77732            1564702200            1564702200            3456789123
# 77733            1564702200            3456789123            3456789123
# 77734            3456789123            3456789123            3456789123
#
#        Decrease_0.4_percent  2H_RA_on_Close
# 41421            1499394600        0.248989
# 41422            1499394600        0.248978
# 41423            1499394600        0.248978
# 41424            1499394600        0.248803
# 41425            1499394600        0.249352
# 41426            1499394600        0.249350
# 41427            1499394600        0.249663
# 41428            1499400000        0.249663
# 41429            1499400000        0.248699
# 41430            1499400000        0.248442
# 41431            1499410800        0.247529
# 41432            1499409000        0.247018
# 41433            1499409000        0.246907
# 41434            1499409000        0.246638
# 41435            1499409000        0.246571
# 41436            1499410800        0.246530
# 41437            1499412600        0.246086
# 41438            1499414400        0.245336
# 41439            1499427000        0.243324
# 41440            1499427000        0.240701
# 41441            1499427000        0.238837
# 41442            1499421600        0.237434
# 41443            1499427000        0.237289
# 41444            1499427000        0.237765
# 41445            1499427000        0.238425
# 41446            1499430600        0.237819
# 41447            1499430600        0.237044
# 41448            1499436000        0.235919
# 41449            1499434200        0.233542
# 41450            1499439600        0.233355
# ...                     ...             ...
# 77705            3456789123        0.314233
# 77706            3456789123        0.314141
# 77707            3456789123        0.313692
# 77708            3456789123        0.313255
# 77709            3456789123        0.312952
# 77710            3456789123        0.312712
# 77711            3456789123        0.312667
# 77712            1564669800        0.312902
# 77713            1564669800        0.313163
# 77714            3456789123        0.313309
# 77715            3456789123        0.313574
# 77716            3456789123        0.313407
# 77717            3456789123        0.313078
# 77718            3456789123        0.312894
# 77719            3456789123        0.312894
# 77720            3456789123        0.312947
# 77721            3456789123        0.313396
# 77722            3456789123        0.313549
# 77723            3456789123        0.313546
# 77724            3456789123        0.313650
# 77725            3456789123        0.313544
# 77726            3456789123        0.313441
# 77727            3456789123        0.313300
# 77728            3456789123        0.313236
# 77729            3456789123        0.313731
# 77730            1564702200        0.314613
# 77731            3456789123        0.315431
# 77732            3456789123        0.315971
# 77733            3456789123        0.316193
# 77734            3456789123        0.316093
#
# [36314 rows x 17 columns]

# %%
time_event = {}
starting_asset = 50
bought_crypto = False


gold_available = starting_asset 
XRP_amount = 0


drop_limit = 0.005 # used mean on this side, actual 0.004686, but decreased abit for optimistic view 

stop_loss_limit = 0.01
sell_limit = 0.006

while gold_available >= 0:
    
    for ind, df in XRP_Analysis_table[XRP_Analysis_table['datetime_real'] > '2017-07-07'].iterrows():
#         print(df['date'])
        
        if bought_crypto != True: # then looking to buy at drop limit or lower
            if ( df['2H_RA_on_Close'] - df['low'] ) / df['2H_RA_on_Close'] >= drop_limit:
                "then buy crypto"

                XRP_amount += (gold_available/df['low']) * 0.998 # due to 0.2% fee

                gold_available -= gold_available
                
                time_event.update({df['date']  : ( gold_available, XRP_amount , 'brought' , df['low'])})
                
                last_xrp_traction_price =  df['low']
                
                bought_crypto = True
                
#                 print('last_xrp_traction_price ', last_xrp_traction_price)
                
        else:
            if bought_crypto: # has crypto, either wait or sell at stoploss or profit
#                 print('hit_sell_limit',
#                       (df['high'] - last_xrp_traction_price)/last_xrp_traction_price >= sell_limit ,
#                       round((df['high'] - last_xrp_traction_price),6) ,
#                       'sell_limit ', sell_limit
                     
#                       )
                
                if ( df['2H_RA_on_Close'] - df['low'] ) / df['2H_RA_on_Close'] >= stop_loss_limit: # then hit stop loss, force sell
#                     print('stoppppppppppppppppppppppppp')
                    gold_available += XRP_amount * df['low'] * 0.998  # sell at low price
                    
                    XRP_amount -= XRP_amount
                    
                    time_event.update({df['date']  : ( gold_available, XRP_amount , 'stop_loss_hit' ,  df['low'])})
                    
                    bought_crypto = False
                    
                    
                
                elif  (df['high'] - last_xrp_traction_price)/last_xrp_traction_price >= sell_limit: # then hit target price, sell for profit
                    
#                     print(last_xrp_traction_price)
                                        
                    gold_available += XRP_amount * df['high'] * 0.998  # sell at high price
                    
                    XRP_amount -= XRP_amount
                    
                    time_event.update({df['date']  : ( gold_available, XRP_amount , 'sell_profit' , df['high'])})
                    
                    bought_crypto = False

    break
                
else:
    print('Negative asset: bankrupt  ->>>   ',  gold_available)

# %%
transation_log = pd.DataFrame.from_dict(time_event, orient='index', columns= ['Gold', 'XRP_Amount', 'action', 'price_action_happened'])

# %%
transation_log['Gold'] = round(transation_log['Gold'], 2)

# %%
transation_log['XRP_Amount'] = round(transation_log['XRP_Amount'], 4)

# %%
transation_log.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dcfe49ea96c4> in <module>
# ----> 1 transation_log.head()
#
# NameError: name 'transation_log' is not defined

# %%
transation_log[transation_log['action'] != 'brought'][['Gold']].plot()

# %%
1499394600

1499517000
# Out:
# 1499517000

# %%
XRP_Analysis_table[XRP_Analysis_table['date'].isin([1499394600,1499517000])]
# Out:
#           close        date        datetime_real    high       low      open  \
# 41428  0.247143  1499394600  2017-07-07 03:30:00  0.2500  0.247143  0.248800
# 41496  0.219800  1499517000  2017-07-08 13:30:00  0.2198  0.219086  0.219086
#
#          quoteVolume        volume  weightedAverage  Increase_0.2_percent  \
# 41428  135533.760057  33550.050609         0.247540            1499396400
# 41496   92286.901180  20281.698605         0.219768            1499518800
#
#        Increase_0.3_percent  Increase_0.4_percent  Decrease_0.1_percent  \
# 41428            1499396400            1499398200            1499398200
# 41496            1499518800            1499520600            1499518800
#
#        Decrease_0.2_percent  Decrease_0.3_percent  Decrease_0.4_percent  \
# 41428            1499398200            1499398200            1499400000
# 41496            1499518800            1499518800            1499518800
#
#        2H_RA_on_Close
# 41428        0.249663
# 41496        0.218102

# %%
transation_log[:50]
# Out:
#               Gold  XRP_Amount         action  price_action_happened
# 1499394600    0.00    403.8141        brought               0.247143
# 1499410800   97.50      0.0000  stop_loss_hit               0.241927
# 1499412600    0.00    409.1813        brought               0.237800
# 1499414400   96.29      0.0000  stop_loss_hit               0.235801
# 1499416200    0.00    407.8941        brought               0.235600
# 1499418000   95.93      0.0000  stop_loss_hit               0.235667
# 1499423400    0.00    405.0872        brought               0.236352
# 1499425200   95.27      0.0000  stop_loss_hit               0.235667
# 1499427000    0.00    405.6490        brought               0.234400
# 1499428800   94.53      0.0000  stop_loss_hit               0.233501
# 1499430600    0.00    410.1387        brought               0.230022
# 1499432400   96.63      0.0000    sell_profit               0.236079
# 1499434200    0.00    419.5498        brought               0.229861
# 1499436000   95.88      0.0000  stop_loss_hit               0.229000
# 1499437800    0.00    416.5830        brought               0.229709
# 1499439600   94.79      0.0000  stop_loss_hit               0.228000
# 1499441400    0.00    415.8302        brought               0.227500
# 1499443200   96.64      0.0000    sell_profit               0.232863
# 1499452200    0.00    414.9715        brought               0.232412
# 1499454000   97.02      0.0000    sell_profit               0.234269
# 1499455800    0.00    418.0757        brought               0.231600
# 1499457600   97.22      0.0000    sell_profit               0.233000
# 1499459400    0.00    421.8364        brought               0.230000
# 1499461200   99.09      0.0000    sell_profit               0.235371
# 1499464800    0.00    431.4615        brought               0.229200
# 1499466600   98.18      0.0000  stop_loss_hit               0.228000
# 1499468400    0.00    435.3704        brought               0.225050
# 1499470200   97.94      0.0000  stop_loss_hit               0.225400
# 1499472000    0.00    432.4798        brought               0.226000
# 1499473800   97.11      0.0000  stop_loss_hit               0.225000
# 1499475600    0.00    446.6515        brought               0.216990
# 1499477400   96.33      0.0000  stop_loss_hit               0.216100
# 1499479200    0.00    449.8864        brought               0.213689
# 1499481000   93.33      0.0000  stop_loss_hit               0.207877
# 1499482800    0.00    442.3183        brought               0.210589
# 1499484600   99.16      0.0000    sell_profit               0.224622
# 1499490000    0.00    449.7075        brought               0.220048
# 1499491800   97.84      0.0000  stop_loss_hit               0.218000
# 1499493600    0.00    454.1603        brought               0.215000
# 1499495400   97.43      0.0000  stop_loss_hit               0.214947
# 1499504400    0.00    446.0111        brought               0.218000
# 1499506200   98.91      0.0000    sell_profit               0.222210
# 1499509800    0.00    456.9994        brought               0.216000
# 1499511600   98.51      0.0000  stop_loss_hit               0.216001
# 1499515200    0.00    454.3319        brought               0.216401
# 1499517000   99.66      0.0000    sell_profit               0.219800
# 1499518800    0.00    459.2018        brought               0.216600
# 1499520600  101.84      0.0000    sell_profit               0.222220
# 1499531400    0.00    446.9457        brought               0.227401
# 1499533200   98.60      0.0000  stop_loss_hit               0.221047
